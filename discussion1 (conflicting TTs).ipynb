# %%
# %reset
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import numpy as np
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
TTS_df=pd.read_table('result/TT_score_viper/TTS_merged.txt', index_col=0)
TTS_df.head()

TTS_df['TTS_diff']=np.abs(TTS_df['TTS_A375']-TTS_df['TTS_HT29'])
TTS_df=TTS_df.drop(['YEATS4','RUVBL1'], axis=0)
TTS_df=TTS_df.sort_values(by='TTS_diff', ascending=False).head(4)
TTS_df[['TFAs Ave.(E)_A375','TFAs Ave.(IE)_A375','TTS_A375','TFAs Ave.(E)_HT29','TFAs Ave.(IE)_HT29','TTS_HT29','TTS_diff']]
# Out:
#       TFAs Ave.(E)_A375  TFAs Ave.(IE)_A375  TTS_A375    p_val_A375  \
# TF
# E4F1              1.572               0.384    11.936  1.148000e-26
# RBL1              1.758               0.452    11.472  2.644000e-24
# E2F4              1.612               0.342    10.852  1.009000e-22
# TP53              2.015               0.544     9.783  1.881000e-18
# RBL2              1.367               0.200    10.737  2.311000e-22
#
#           FDR_A375  negLog10_FDR_A375  TFAs Ave.(E)_HT29  TFAs Ave.(IE)_HT29  \
# TF
# E4F1  7.198000e-24             23.143              1.553               0.255
# RBL1  1.658000e-21             20.781              1.454               0.229
# E2F4  6.324000e-20             19.199              1.964               0.601
# TP53  1.179000e-15             14.928              1.777               0.202
# RBL2  1.449000e-19             18.839              1.306               0.293
#
#       TTS_HT29    p_val_HT29      FDR_HT29  negLog10_FDR_HT29  TTS_SUM
# TF
# ...
